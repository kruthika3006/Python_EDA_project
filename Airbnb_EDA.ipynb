# %% [markdown]
# <a href="https://colab.research.google.com/github/kruthika3006/Python_EDA_project/blob/main/Airbnb_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Airbnb Python EDA Project**

# %% [markdown]
# **STEPS**
#
#
#
# 1.   Importing all libraries
# 2.   Loading Dataset
# 3.   Data Exploration
# 4.   Data Cleaning
# 5.   Data Analysis

# %% [markdown]
# **Task 1: Importing all Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Task 2: Loading Dataset**

# %%
from google.colab import files
uploaded = files.upload()


df = pd.read_csv('airbnb.csv', encoding='latin1')  # or encoding='latin1'
df.head()
# Out:
#      <input type="file" id="files-6476f217-cb41-4f54-8454-546cc7cce18d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6476f217-cb41-4f54-8454-546cc7cce18d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Task 3: Data Exploration**

# %%
df.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ?5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ?4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ?4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ?4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ?4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
df.tail()
# Out:
#                  id                                               name  \
# 20765  2.473690e+07  Rental unit in New York · ?4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ?4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ?4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ?5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ?4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20765  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20766    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20767  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20768  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20769   93827372   Glenroy              Queens           Rosedale  40.658874
#
# ...

# %%
df.shape
# Out:
# (20770, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
#satistical summary
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %% [markdown]
# **Task 4: Data Cleaning**

# %%
df.isnull().sum()

#dropping the missing value rows
df.dropna(inplace=True)

df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
# Handling duplicate datas
df.duplicated().sum()

#dropping duplicate records
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Type casting
df.dtypes

df['id']=df['id'].astype(object)
df.dtypes
df['host_id']=df['host_id'].astype(object)
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# ## **EDA**

# %% [markdown]
# ## **Task 5: Data Analysis**

# %% [markdown]
# **Univariate Analysis**

# %%
plt.figure(figsize=(4,2))
sns.boxplot(data=df,x='price')
plt.show()

# %%
data=df[df['price']<1500]

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data=data,x='price')
plt.show()

# %%
# Data distribution of each columns
plt.figure(figsize=(4,3))
sns.histplot(data=data,x='price',bins=100)
plt.title('Price distribution')
plt.ylabel('Frequency')
plt.show()

# %%
data.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  20636.000000  20636.000000  20636.000000    20636.000000
# mean      40.726792    -73.939033    165.289252       28.580103
# std        0.060379      0.061456    147.139696       33.614895
# min       40.500314    -74.249840     10.000000        1.000000
# 25%       40.684126    -73.980614     80.000000       30.000000
# 50%       40.722730    -73.949490    125.000000       30.000000
# 75%       40.763171    -73.917315    199.000000       30.000000
# max       40.911147    -73.713650   1499.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       20636.000000       20636.000000                    20636.000000
# mean           42.670721           1.260605                       18.905311
# std            73.597800           1.907277                       71.088461
# min             1.000000           0.010000                        1.000000
# ...

# %%
#Data distribution of availability_365
plt.figure(figsize=(4,3))
sns.histplot(data=df,x='availability_365')
plt.title('Availability_365distribution')
plt.ylabel('Frequency')
plt.show()

# %%
data.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            107.990506
# Brooklyn         155.138317
# Manhattan        204.146014
# Queens           121.681939
# Staten Island    118.780069
# Name: price, dtype: float64

# %% [markdown]
# # **Feature Engineering**

# %%
# Adding "Price Per bed" column
data['price per bed']= data['price']/data['beds']
data.head()
# Out:
# <ipython-input-20-14dbcd0410f4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price per bed']= data['price']/data['beds']
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ?5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ?4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ?4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ?4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ?4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# ...

# %%
#Average price per bed
data.groupby('neighbourhood_group')['price per bed'].mean()
# Out:
# neighbourhood_group
# Bronx             74.713639
# Brooklyn          99.788493
# Manhattan        138.708057
# Queens            76.336210
# Staten Island     67.728101
# Name: price per bed, dtype: float64

# %% [markdown]
# **Bi variate analysis**

# %%
#Price dependency on room type
plt.figure(figsize=(4,3))
sns.barplot(data=data,x='neighbourhood_group',y='price',hue='room_type')
plt.show()

# %%
#Price relationship with no of Reviews
plt.figure(figsize=(4,3))
sns.scatterplot(data=data,x='number_of_reviews',y='price',hue='neighbourhood_group')
plt.title('Locality and Review Dependency')
plt.show()

# %%
plt.figure(figsize=(3,1))
sns.pairplot(data=data,vars=['price','minimum_nights','number_of_reviews','availability_365'],hue='room_type')
plt.show()

# %%
#geographical distribution of airbnb listing
plt.figure(figsize=(4,3))
sns.scatterplot(data=data,x='longitude',y='latitude',hue='room_type')
plt.title("Geographical distribution of airbnb listing")
plt.show()

# %%
data.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# ...

# %%
#heatmap : To see correlation between numerical columns
plt.figure(figsize=(6,5))
corr=data[['latitude','longitude','price','minimum_nights','number_of_reviews',
           'reviews_per_month','availability_365','beds']].corr()
corr
sns.heatmap(data=corr,annot=True)
plt.show()
